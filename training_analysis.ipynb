# %% [markdown]
# ### Debug and analyse the training and testing of the model

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('training_loss.csv')

plt.plot(df['training_loss'])
